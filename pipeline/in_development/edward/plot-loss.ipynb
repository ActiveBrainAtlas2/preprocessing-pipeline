# %%
import cv2
import os
import numpy as np
from skimage import io
from matplotlib import pyplot as plt

# %%
l1 = [0.1617,0.0790,0.0749,0.0631,0.0656,0.0614,0.0592,0.0635,0.0643,0.0575,0.0568,0.0584,0.0603,0.0607,0.0577,
0.0608,0.0584,0.0611,0.0581,0.0593]
l2 = [0.2261,0.1088,0.0927,0.0784,0.0743,0.0728,0.0711,0.0709,0.0710,0.0707,0.0706,0.0707,0.0707,0.0706,0.0705,
0.0701,0.0702,0.0703,0.0706,0.0711]

# %%
l3 = [0.0954,0.0841,0.0780,0.0615,0.0641,0.0583,0.0564,0.0585,0.0609,0.0602,0.0650,0.0576,0.0565,0.0580,0.0567,
0.0589,0.0592,0.0596,0.0614,0.0592,]
l4 = [0.2609,0.1054,0.0931,0.0761,0.0740,0.0723,0.0710,0.0709,0.0704,0.0703,0.0704,0.0705,
0.0704,0.0707,0.0706,0.0702,0.0704,0.0705,0.0704,0.0705]

# %%
x = [i for i in range(len(l1))]

# %%
plt.figure(num = 3, figsize=(8, 5))
plt.plot(x, l1,  color='green', linestyle='dashed', marker='o',
     markerfacecolor='blue', markersize=5)
plt.plot(x, l2, color='red', linewidth=1.0,  linestyle='--' )
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Loss over {len(x)} epochs')
plt.show()

# %%
plt.figure(num = 3, figsize=(8, 5))
plt.plot(x, l3,  color='green', linestyle='dashed', marker='o',
     markerfacecolor='blue', markersize=5)
plt.plot(x, l4, color='red', linewidth=1.0,  linestyle='--' )
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Loss over {len(x)} epochs')
plt.show()
