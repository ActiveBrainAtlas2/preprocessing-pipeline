# %%
import matplotlib.pyplot as plt
from tifffile import imread
import os
import numpy as np
from scipy.signal import argrelextrema,find_peaks
from concurrent.futures.process import ProcessPoolExecutor
import cv2
import sys
sys.path.append('/scratch/programming/pipeline_utility/in_development/Will')
from cell_extractor.BorderFinder import BorderFinder
def find_border(max_con,shape):
    mask = np.zeros(shape)
    mask = cv2.fillPoly(mask, pts =[max_con.reshape(-1,1,2)], color=(255,255,255))
    kernel   = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (100,100))
    morphed  = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    kernel   = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (50,50))
    eroded  = cv2.morphologyEx(mask, cv2.MORPH_ERODE, kernel)
    return morphed-eroded
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d60796e01ac1> in <module>
#       8 import sys
#       9 sys.path.append('/scratch/programming/pipeline_utility/in_development/Will')
# ---> 10 from cell_extractor.BorderFinder import BorderFinder
#      11 def find_border(max_con,shape):
#      12     mask = np.zeros(shape)
#
# /scratch/programming/pipeline_utility/in_development/Will/cell_extractor/BorderFinder.py in <module>
# ----> 1 from .CellDetectorBase import CellDetectorBase
#       2 import os
#       3 import matplotlib.pyplot as plt
#       4 from tifffile import imread
#       5 import numpy as np
#
# /scratch/programming/pipeline_utility/in_development/Will/cell_extractor/CellDetectorBase.py in <module>
#       2 from time import time
#       3 from glob import glob
# ----> 4 from abakit.lib.Brain import Brain
#       5 import pickle as pkl
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'abakit.lib.Brain'

# %%
finder = BorderFinder(animal = 'DK41')
# finder.find_max_contour()
# finder.find_border_regions()

# %%
import pickle
pickle.dump(finder.borders,open(finder.BORDER_INFO,'wb'))

# %%
import sys
sys.path.append('/scratch/programming/pipeline_utility/in_development/Will')
from cell_extractor.CellDetectorBase import CellDetectorBase
animal = 'DK41'
base = CellDetectorBase(animal,round = 2)
detections = base.load_detections()
sure = detections[detections.predictions==2]
unsure = detections[detections.predictions==0]

# %%
border_cell,sure = finder.find_border_cells(sure)
border_cell,unsure = finder.find_border_cells(unsure)

# %%
df = sure[sure.section==180]
scale_factor = 0.03125
data = np.array([df.row.to_list(),df.col.to_list()])*scale_factor
# Out:
# ((2, 39), array([ 760.9375, 1494.    ]))

# %%
import pandas as pd
cells = sure
border_cell =[]
good_cell = []
for sectioni in cells.section.unique():
    df = cells[cells.section==sectioni]
    scale_factor = 0.03125
    data = np.array([df.row.to_list(),df.col.to_list()])*scale_factor
    border = finder.borders[sectioni]
    npoints = data.shape[1]
    on_border = []
    for i in range(npoints):
        point = data[:,i].astype(int)
        on_border.append(border[point[0],point[1]]>0)
    on_border = np.array(on_border)
    border_cell.append(df[on_border])
    good_cell.append(df[np.logical_not(on_border)])
border_cell = pd.concat(border_cell)
good_cell = pd.concat(good_cell)

# %%
len(good_cell),len(border_cell),len(cells)
# Out:
# (5058, 591, 5649)

# %%
plt.figure(figsize=[20,20])
plt.imshow(finder.borders[180])
plt.scatter(data[1][on_border],data[0][on_border])
plt.scatter(data[1][on_border==False],data[0][on_border==False])

# %%
plt.figure(figsize=[20,40])
i=1
bins = np.linspace(0,2000,100)
threshold = []
for file in files:
    img = imread(folder+file)
    plt.subplot(40,10,i)
    plt.imshow(imgs[i-1]>500)
    max_con = max_contours[i-1]
    plt.scatter(max_con[:,0],max_con[:,1])
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-bc6e2b6dc414> in <module>
#       5 for file in files:
#       6     img = imread(folder+file)
# ----> 7     plt.subplot(40,10,i)
#       8     plt.imshow(imgs[i-1]>500)
#       9     max_con = max_contours[i-1]
#
# /usr/local/share/pipeline/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# /usr/local/share/pipeline/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# /usr/local/share/pipeline/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# /usr/local/share/pipeline/lib/python3.6/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     688                 if num < 1 or num > rows*cols:
#     689                     raise ValueError(
# --> 690                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     691                 return gs[num - 1]   # -1 due to MATLAB indexing.
#     692         else:
#
# ValueError: num must be 1 <= num <= 400, not 401

# %%
plt.imshow(img>500)
plt.scatter(max_con[:,0],max_con[:,1])

# %%
# mask = img>500
mask = np.zeros(img.shape)
mask = cv2.fillPoly(mask, pts =[max_con.reshape(-1,1,2)], color=(255,255,255))
kernel   = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (100,100))
morphed  = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
kernel   = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (50,50))
eroded  = cv2.morphologyEx(mask, cv2.MORPH_ERODE, kernel)
plt.figure()
plt.imshow(mask)
plt.figure()
plt.imshow(eroded)
plt.figure()
plt.imshow(morphed-eroded)

# %%
bins = np.linspace(0,2000,100)
peaks = find_peaks(-line,prominence=10)[0][0]
line,bins = np.histogram(data,bins)
plt.plot(line)
plt.scatter(peaks,line[peaks],color='r')
