# %%
'''
This notebook used for czi file renaming to support DK84 processing
Contact Duane Rinehart (drinehart@ucsd.edu) for details
'''
from os import listdir
import os
import re
import shutil

#REPLACEMENTS PATHS
DATA_PATH = "/net/birdstore/Active_Atlas_Data/data_root"
src_dir = os.path.join(DATA_PATH, "pipeline_data", "DK84", "czi_org")
dest_dir = os.path.join(DATA_PATH, "pipeline_data", "DK84", "czi_temp")

#REORDER DICTIONARY (SRC, DEST)
dict_replacements = {'DK84_slide019_2022_08_17_axion2_15-20-13.czi':50,
'DK84_slide020_2022_08_17_axion2_15-24-59_S1_C1.tif':51,
'DK84_slide021_2022_08_17_axion2_15-30-14_S1_C1.tif':52,
'DK84_slide022_2022_08_17_axion2_15-35-02_S1_C1.tif':53,
'DK84_slide023_2022_08_17_axion2_15-39-50_S1_C1.tif':54,
'DK84_slide024_2022_08_17_axion2_15-44-38_S1_C1.tif':55,
'DK84_slide025_2022_08_18_axion2_12-08-08_S1_C1.tif':56,
'DK84_slide026_2022_08_18_axion2_12-13-03_S1_C1.tif':57,
'DK84_slide027_2022_08_18_axion2_12-17-55_S1_C1.tif':58,
'DK84_slide028_2022_08_18_axion2_12-22-44_S1_C1.tif':59,
'DK84_slide029_2022_08_18_axion2_12-28-01_S1_C1.tif':60,
'DK84_slide030_2022_08_18_axion2_12-32-49_S1_C1.tif':61,
'DK84_slide031_2022_08_18_axion2_12-37-41_S1_C1.tif':62,
'DK84_slide032_2022_08_18_axion2_12-42-29_S1_C1.tif':63,
'DK84_slide033_2022_08_18_axion2_12-47-44_S1_C1.tif':64,
'DK84_slide034_2022_08_18_axion2_12-52-38_S1_C1.tif':65,
'DK84_slide035_2022_08_18_axion2_12-57-28_S1_C1.tif':66,
'DK84_slide036_2022_08_18_axion2_13-02-18_S1_C1.tif':67,
'DK84_slide037_2022_08_18_axion2_13-07-36_S1_C1.tif':68,
'DK84_slide038_2022_08_18_axion2_13-12-24_S1_C1.tif':69,
'DK84_slide039_2022_08_18_axion2_13-17-11_S1_C1.tif':70,
'DK84_slide040_2022_08_18_axion2_13-22-02_S1_C1.tif':71,
'DK84_slide041_2022_08_18_axion2_13-27-19_S1_C1.tif':72,
'DK84_slide042_2022_08_18_axion2_13-32-09_S1_C1.tif':73,
'DK84_slide043_2022_08_18_axion2_13-36-58_S1_C1.tif':74,
'DK84_slide044_2022_08_18_axion2_13-41-51_S1_C1.tif':75,
'DK84_slide045_2022_08_18_axion2_13-47-07_S1_C1.tif':76,
'DK84_slide046_2022_08_18_axion2_13-51-59_S1_C1.tif':77,
'DK84_slide047_2022_08_18_axion2_13-56-52_S1_C1.tif':78,
'DK84_slide048_2022_08_18_axion2_14-01-46_S1_C1.tif':79,
'DK84_slide049_2022_08_18_axion2_14-07-03_S1_C1.tif':80,
'DK84_slide050_2022_08_18_axion2_14-11-51_S1_C1.tif':81,
'DK84_slide051_2022_08_18_axion2_14-16-45_S1_C1.tif':82,
'DK84_slide052_2022_08_18_axion2_14-21-35_S1_C1.tif':83,
'DK84_slide053_2022_08_18_axion2_14-26-53_S1_C1.tif':84,
'DK84_slide054_2022_08_18_axion2_14-31-45_S1_C1.tif':85,
'DK84_slide055_2022_08_18_axion2_14-36-39_S1_C1.tif':86,
'DK84_slide056_2022_08_18_axion2_14-41-27_S1_C1.tif':87,
'DK84_slide057_2022_08_18_axion2_14-46-45_S1_C1.tif':88,
'DK84_slide109_2022_08_23_axion2_12-05-29_S1_C1.tif':148,
'DK84_slide110_2022_08_23_axion2_12-10-12_S1_C1.tif':149,
'DK84_slide111_2022_08_23_axion2_12-15-22_S1_C1.tif':150,
'DK84_slide112_2022_08_23_axion2_12-20-02_S1_C1.tif':151,
'DK84_slide113_2022_08_23_axion2_12-24-41_S1_C1.tif':152,
'DK84_slide114_2022_08_23_axion2_12-29-26_S1_C1.tif':153,
'DK84_slide115_2022_08_23_axion2_12-34-42_S1_C1.tif':154,
'DK84_slide116_2022_08_23_axion2_12-39-18_S1_C1.tif':155,
'DK84_slide117_2022_08_23_axion2_12-43-59_S1_C1.tif':156,
'DK84_slide118_2022_08_23_axion2_12-48-45_S1_C1.tif':157,
'DK84_slide119_2022_08_23_axion2_12-53-59_S1_C1.tif':158,
'DK84_slide120_2022_08_23_axion2_12-58-38_S1_C1.tif':159,
'DK84_slide121_2022_08_23_axion2_13-03-13_S1_C1.tif':160,
'DK84_slide122_2022_08_23_axion2_13-07-59_S1_C1.tif':161,
'DK84_slide123_2022_08_23_axion2_13-13-07_S1_C1.tif':162,
'DK84_slide124_2022_08_23_axion2_13-17-48_S1_C1.tif':163,
'DK84_slide125_2022_08_23_axion2_13-22-34_S1_C1.tif':164
}

#REFORMAT REPLACEMENT DICTIONARY FOR EXACT MATCHING
exact_replacements = {}
for src, dest in dict_replacements.items():
    src_slide_number = str(re.findall(r"slide\d+", src))[2:-2]
    dest_slide_number = 'slide' + str(dest).zfill(3)
    exact_replacements[src_slide_number] = dest_slide_number

#print(exact_replacements)

#REPLACE FROM DICT WHERE FILES HAVE EXACT MATCH
for src_filename in listdir(src_dir):
    src_slide_number = str(re.findall(r"slide\d+", src_filename))[2:-2]
    d = {k : v for d in exact_replacements for k, v in exact_replacements.items()}
    try:
        dest_slide_number = d[src_slide_number]
        #print(src_slide_number, dest_slide_number)
        dest_filename = src_filename.replace(src_slide_number, dest_slide_number)
        #print(f"SRC: {src_filename} -> DEST: {dest_filename}")

        src_full_path = os.path.join(src_dir, src_filename)
        dest_full_path = os.path.join(dest_dir, dest_filename)
        print(f"SRC: {src_full_path} -> DEST: {dest_full_path}")
        shutil.copyfile(src_full_path, dest_full_path)
    except:
        pass
# Out:
# SRC: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_org/DK84_slide121_2022_08_23_axion2_13-03-13.czi -> DEST: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_temp/DK84_slide160_2022_08_23_axion2_13-03-13.czi
# SRC: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_org/DK84_slide038_2022_08_18_axion2_13-12-24.czi -> DEST: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_temp/DK84_slide069_2022_08_18_axion2_13-12-24.czi
# SRC: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_org/DK84_slide061_2022_08_18_axion2_15-06-32.czi -> DEST: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_temp/DK84_slide092_2022_08_18_axion2_15-06-32.czi
# SRC: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_org/DK84_slide117_2022_08_23_axion2_12-43-59.czi -> DEST: /net/birdstore/Active_Atlas_Data/data_root/pipeline_data/DK84/czi_temp/DK84_slide156_2022_08_23_axion2_12-43-59.czi
# ...
