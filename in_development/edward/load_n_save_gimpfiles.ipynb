# %%
import os
import numpy as np
from skimage import io
from matplotlib import pyplot as plt

# %%
animal = 'DK73'
DIR = f'/net/birdstore/Active_Atlas_Data/data_root/pipeline_data/{animal}/preps'
INPUT = os.path.join(DIR, 'CH1', 'thumbnail_cleaned')

# %%
# test if readable, corrupted
badfiles = ['138.tif','139.tif',
            '143.tif', '144.tif','147.tif',
            '155.tif',
            '163.tif','167.tif',
            '171.tif','175.tif','179.tif',
            '180.tif','183.tif','184.tif','187.tif','188.tif','189.tif',
            '195.tif','197.tif']
for badfile in badfiles:
    badpath = os.path.join(INPUT, badfile)
    badarr = io.imread(badpath)
    print(badfile,badarr.dtype, badarr.shape)
# Out:
# 138.tif uint16 (1796, 2703)
# 139.tif uint16 (1796, 2703)
# 143.tif uint16 (1796, 2703)
# 144.tif uint16 (1796, 2703)
# 147.tif uint16 (1796, 2703)
# 155.tif uint16 (1796, 2703)
# 163.tif uint16 (1796, 2703)
# 167.tif uint16 (1796, 2703)
# 171.tif uint16 (1796, 2703)
# 175.tif uint16 (1796, 2703)
# 179.tif uint16 (1796, 2703)
# 180.tif uint16 (1796, 2703)
# 183.tif uint16 (1796, 2703)
# 184.tif uint16 (1796, 2703)
# 187.tif uint16 (1796, 2703)
# 188.tif uint16 (1796, 2703)
# 189.tif uint16 (1796, 2703)
# 195.tif uint16 (1796, 2703)
# 197.tif uint16 (1796, 2703)

# %%
for badfile in badfiles:
    badpath = os.path.join(INPUT, badfile)
    badarr = io.imread(badpath)
    print(badarr.dtype, badarr.shape)
    io.imsave(badpath, badarr)
# Out:
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)
# uint16 (1796, 2703)

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
for goodfile in badfiles:
    goodpath = os.path.join(INPUT, goodfile)
    goodarr = io.imread(goodpath)
    # Plot the data using imshow with gray colormap
    plt.imshow(goodarr, cmap='gray')
    # Display the plot
    plt.show()
