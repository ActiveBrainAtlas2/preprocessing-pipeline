# %%
import sys
sys.path.append('/home/zhw272/programming/preprocessing-pipeline/in_development/Will')
from cell_extractor.CellDetectorBase import CellDetectorBase
from cell_extractor.CellDetector import CellDetector,detect_cell
from cell_extractor.Predictor import Predictor
# Out:
# /usr/local/share/pipeline/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
thresholds = [2000,2100,2200,2300,2700]
for threshold in thresholds:
    detector =CellDetector(animal='DK55',round=2,segmentation_threshold = threshold)
    detector.save_models(detector.detector.model)
# Out:
# version of xgboost is: 1.5.0 should be at least 1.5.0
# version of xgboost is: 1.5.0 should be at least 1.5.0
# version of xgboost is: 1.5.0 should be at least 1.5.0
# version of xgboost is: 1.5.0 should be at least 1.5.0
# version of xgboost is: 1.5.0 should be at least 1.5.0

# %%
detector =CellDetector(animal='DK40',round=2,segmentation_threshold = 2000)
features = detector.get_combined_features_for_detection()
detector.detector.plot_decision_scatter(features)
# Out:
# version of xgboost is: 1.5.0 should be at least 1.5.0
# /usr/local/share/pipeline/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
detector.detector.predictor = Predictor()
detector.detector.plot_score_scatter(features)
# Out:
# /usr/local/share/pipeline/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
thresholds = [2000,2100,2200,2300,2700]
detectors = {}
features = {}
for threshold in thresholds:
    detectors[threshold] =CellDetector(animal='DK40',round=2,segmentation_threshold = threshold)
    features[threshold] = detector.get_combined_features_for_detection()
    detectors[threshold].detector.predictor = Predictor()
    detectors[threshold].detector.plot_score_scatter(features[threshold])
# Out:
# version of xgboost is: 1.5.0 should be at least 1.5.0
# /usr/local/share/pipeline/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# version of xgboost is: 1.5.0 should be at least 1.5.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/zhw272/programming/preprocessing-pipeline/in_development/Will/cell_extractor/retraining/multi_threshold.ipynb Cell 4' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/zhw272/programming/preprocessing-pipeline/in_development/Will/cell_extractor/retraining/multi_threshold.ipynb#ch0000001?line=2'>3</a> features = {}
# ...
