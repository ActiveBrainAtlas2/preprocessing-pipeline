# %%
import sys
sys.path.append('/home/zhw272/programming/pipeline_utility')
from toolbox.rough_alignment.rough_alignment_demons import get_rough_alignment_demons_transform
import SimpleITK as sitk

# %%
list_of_brains_to_align = ['DK39', 'DK41', 'DK43', 'DK54', 'DK55']
save_path = '/net/birdstore/Active_Atlas_Data/data_root/tfm'
for braini in list_of_brains_to_align:
    transformi = get_rough_alignment_demons_transform(fixed_brain = braini)
    sitk.WriteTransform(transformi, save_path+'/demons/'+braini+'_demons.tfm')
# Out:
# aligning brain DK52 to brain DK39
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 82439044.022302
# iteration: 20 79878265.192359
# iteration: 30 77821516.557138
# iteration: 40 76106453.863687
# iteration: 50 74582341.539955
# iteration: 60 73222480.417440
# iteration: 70 72009799.365785
# iteration: 80 70922318.492615
# iteration: 90 69946471.883296
# iteration: 100 69081581.230034
# itk::simple::DisplacementFieldTransform
#  GaussianSmoothingOnUpdateDisplacementFieldTransform (0x2e26c90)
#    RTTI typeinfo:   itk::GaussianSmoothingOnUpdateDisplacementFieldTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 216532
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    DisplacementField:
#      Image (0x38644f0)
#        RTTI typeinfo:   itk::Image<itk::Vector<double, 3u>, 3u>
#        Reference Count: 3
#        Modified Time: 190417
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        Source: (none)
#        Source output name: (none)
#        Release Data: Off
#        Data Released: False
#        Global Release Data: Off
#        PipelineMTime: 0
#        UpdateMTime: 190410
#        RealTimeStamp: 0 seconds
#        LargestPossibleRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [435, 262, 117]
#        BufferedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [435, 262, 117]
#        RequestedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [435, 262, 117]
#        Spacing: [41.6, 41.6, 80]
#        Origin: [31.2, 26, 40]
#        Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        IndexToPointMatrix:
# 41.6 0 0
# 0 41.6 0
# 0 0 80
#
#        PointToIndexMatrix:
# 0.0240385 0 0
# 0 0.0240385 0
# 0 0 0.0125
#
#        Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        PixelContainer:
#          ImportImageContainer (0x3864780)
#            RTTI typeinfo:   itk::ImportImageContainer<unsigned long, itk::Vector<double, 3u> >
#            Reference Count: 1
#            Modified Time: 190408
#            Debug: Off
#            Object Name:
#            Observers:
#              none
#            Pointer: 0x388efb0
#            Container manages memory: true
#            Size: 13334490
#            Capacity: 13334490
#    InverseDisplacementField: (null)
#    Interpolator:
#      VectorLinearInterpolateImageFunction (0x3661660)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 189931
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0x38644f0
#        StartIndex: [0, 0, 0]
#        EndIndex: [434, 261, 116]
#        StartContinuousIndex: [-0.5, -0.5, -0.5]
#        EndContinuousIndex: [434.5, 261.5, 116.5]
#    InverseInterpolator:
#      VectorLinearInterpolateImageFunction (0x3601fa0)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 189932
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0
#        StartIndex: [0, 0, 0]
#        EndIndex: [0, 0, 0]
#        StartContinuousIndex: [0, 0, 0]
#        EndContinuousIndex: [0, 0, 0]
#    DisplacementFieldSetTime: 190418
#    m_IdentityJacobian: [1, 0, 0]
# [0, 1, 0]
# [0, 0, 1]
#
#     CoordinateTolerance: 1e-06
#     DirectionTolerance: 1e-06
#    Gaussian smoothing parameters:
#    m_GaussianSmoothingVarianceForTheUpdateField: 0
#    m_GaussianSmoothingVarianceForTheTotalField: 2
#
# aligning brain DK52 to brain DK41
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 70194524.755914
# iteration: 20 67576092.381499
# iteration: 30 65258999.493923
# iteration: 40 63227785.572636
# iteration: 50 61498315.901207
# iteration: 60 60012968.153407
# iteration: 70 58662414.130356
# iteration: 80 57382022.373295
# iteration: 90 56308198.456044
# iteration: 100 55461718.974504
# itk::simple::DisplacementFieldTransform
#  GaussianSmoothingOnUpdateDisplacementFieldTransform (0x27eaad0)
#    RTTI typeinfo:   itk::GaussianSmoothingOnUpdateDisplacementFieldTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 432137
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    DisplacementField:
#      Image (0x37e7360)
#        RTTI typeinfo:   itk::Image<itk::Vector<double, 3u>, 3u>
#        Reference Count: 3
#        Modified Time: 406022
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        Source: (none)
#        Source output name: (none)
#        Release Data: Off
#        Data Released: False
#        Global Release Data: Off
#        PipelineMTime: 0
#        UpdateMTime: 406015
#        RealTimeStamp: 0 seconds
#        LargestPossibleRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [450, 250, 116]
#        BufferedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [450, 250, 116]
#        RequestedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [450, 250, 116]
#        Spacing: [41.6, 41.6, 80]
#        Origin: [15.6, 15.6, 60]
#        Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        IndexToPointMatrix:
# 41.6 0 0
# 0 41.6 0
# 0 0 80
#
#        PointToIndexMatrix:
# 0.0240385 0 0
# 0 0.0240385 0
# 0 0 0.0125
#
#        Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        PixelContainer:
#          ImportImageContainer (0x381a750)
#            RTTI typeinfo:   itk::ImportImageContainer<unsigned long, itk::Vector<double, 3u> >
#            Reference Count: 1
#            Modified Time: 406013
#            Debug: Off
#            Object Name:
#            Observers:
#              none
#            Pointer: 0x169c2c30
#            Container manages memory: true
#            Size: 13050000
#            Capacity: 13050000
#    InverseDisplacementField: (null)
#    Interpolator:
#      VectorLinearInterpolateImageFunction (0x388e320)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 405537
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0x37e7360
#        StartIndex: [0, 0, 0]
#        EndIndex: [449, 249, 115]
#        StartContinuousIndex: [-0.5, -0.5, -0.5]
#        EndContinuousIndex: [449.5, 249.5, 115.5]
#    InverseInterpolator:
#      VectorLinearInterpolateImageFunction (0x37d7990)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 405538
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0
#        StartIndex: [0, 0, 0]
#        EndIndex: [0, 0, 0]
#        StartContinuousIndex: [0, 0, 0]
#        EndContinuousIndex: [0, 0, 0]
#    DisplacementFieldSetTime: 406023
#    m_IdentityJacobian: [1, 0, 0]
# [0, 1, 0]
# [0, 0, 1]
#
#     CoordinateTolerance: 1e-06
#     DirectionTolerance: 1e-06
#    Gaussian smoothing parameters:
#    m_GaussianSmoothingVarianceForTheUpdateField: 0
#    m_GaussianSmoothingVarianceForTheTotalField: 2
#
# aligning brain DK52 to brain DK43
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 80711180.977451
# iteration: 20 78851657.680180
# iteration: 30 77076293.523230
# iteration: 40 75096555.355997
# iteration: 50 73679489.753866
# iteration: 60 72096798.983111
# iteration: 70 70387013.714689
# iteration: 80 69057376.525218
# iteration: 90 67764733.479770
# iteration: 100 66542505.798387
# itk::simple::DisplacementFieldTransform
#  GaussianSmoothingOnUpdateDisplacementFieldTransform (0x2708a80)
#    RTTI typeinfo:   itk::GaussianSmoothingOnUpdateDisplacementFieldTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 632892
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    DisplacementField:
#      Image (0x383a310)
#        RTTI typeinfo:   itk::Image<itk::Vector<double, 3u>, 3u>
#        Reference Count: 3
#        Modified Time: 606777
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        Source: (none)
#        Source output name: (none)
#        Release Data: Off
#        Data Released: False
#        Global Release Data: Off
#        PipelineMTime: 0
#        UpdateMTime: 606770
#        RealTimeStamp: 0 seconds
#        LargestPossibleRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [421, 250, 98]
#        BufferedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [421, 250, 98]
#        RequestedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [421, 250, 98]
#        Spacing: [41.6, 41.6, 80]
#        Origin: [31.2, 15.6, 30]
#        Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        IndexToPointMatrix:
# 41.6 0 0
# 0 41.6 0
# 0 0 80
#
#        PointToIndexMatrix:
# 0.0240385 0 0
# 0 0.0240385 0
# 0 0 0.0125
#
#        Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        PixelContainer:
#          ImportImageContainer (0x3866050)
#            RTTI typeinfo:   itk::ImportImageContainer<unsigned long, itk::Vector<double, 3u> >
#            Reference Count: 1
#            Modified Time: 606768
#            Debug: Off
#            Object Name:
#            Observers:
#              none
#            Pointer: 0x294739c0
#            Container manages memory: true
#            Size: 10314500
#            Capacity: 10314500
#    InverseDisplacementField: (null)
#    Interpolator:
#      VectorLinearInterpolateImageFunction (0x3882f60)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 606292
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0x383a310
#        StartIndex: [0, 0, 0]
#        EndIndex: [420, 249, 97]
#        StartContinuousIndex: [-0.5, -0.5, -0.5]
#        EndContinuousIndex: [420.5, 249.5, 97.5]
#    InverseInterpolator:
#      VectorLinearInterpolateImageFunction (0x38593e0)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 606293
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0
#        StartIndex: [0, 0, 0]
#        EndIndex: [0, 0, 0]
#        StartContinuousIndex: [0, 0, 0]
#        EndContinuousIndex: [0, 0, 0]
#    DisplacementFieldSetTime: 606778
#    m_IdentityJacobian: [1, 0, 0]
# [0, 1, 0]
# [0, 0, 1]
#
#     CoordinateTolerance: 1e-06
#     DirectionTolerance: 1e-06
#    Gaussian smoothing parameters:
#    m_GaussianSmoothingVarianceForTheUpdateField: 0
#    m_GaussianSmoothingVarianceForTheTotalField: 2
#
# aligning brain DK52 to brain DK54
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 74925622.420463
# iteration: 20 73177018.787093
# iteration: 30 72357926.718299
# iteration: 40 71811547.343213
# iteration: 50 71313972.136094
# iteration: 60 70942230.138826
# iteration: 70 70538690.280334
# iteration: 80 70128300.751334
# iteration: 90 69830682.476734
# iteration: 100 69465577.445640
# itk::simple::DisplacementFieldTransform
#  GaussianSmoothingOnUpdateDisplacementFieldTransform (0x3819e20)
#    RTTI typeinfo:   itk::GaussianSmoothingOnUpdateDisplacementFieldTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 832063
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    DisplacementField:
#      Image (0x62e57800)
#        RTTI typeinfo:   itk::Image<itk::Vector<double, 3u>, 3u>
#        Reference Count: 3
#        Modified Time: 805948
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        Source: (none)
#        Source output name: (none)
#        Release Data: Off
#        Data Released: False
#        Global Release Data: Off
#        PipelineMTime: 0
#        UpdateMTime: 805941
#        RealTimeStamp: 0 seconds
#        LargestPossibleRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 296, 96]
#        BufferedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 296, 96]
#        RequestedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 296, 96]
#        Spacing: [41.6, 41.6, 80]
#        Origin: [31.2, 31.2, 30]
#        Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        IndexToPointMatrix:
# 41.6 0 0
# 0 41.6 0
# 0 0 80
#
#        PointToIndexMatrix:
# 0.0240385 0 0
# 0 0.0240385 0
# 0 0 0.0125
#
#        Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        PixelContainer:
#          ImportImageContainer (0x3858a20)
#            RTTI typeinfo:   itk::ImportImageContainer<unsigned long, itk::Vector<double, 3u> >
#            Reference Count: 1
#            Modified Time: 805939
#            Debug: Off
#            Object Name:
#            Observers:
#              none
#            Pointer: 0x38088230
#            Container manages memory: true
#            Size: 13298688
#            Capacity: 13298688
#    InverseDisplacementField: (null)
#    Interpolator:
#      VectorLinearInterpolateImageFunction (0x388c710)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 805463
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0x62e57800
#        StartIndex: [0, 0, 0]
#        EndIndex: [467, 295, 95]
#        StartContinuousIndex: [-0.5, -0.5, -0.5]
#        EndContinuousIndex: [467.5, 295.5, 95.5]
#    InverseInterpolator:
#      VectorLinearInterpolateImageFunction (0x37bfe90)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 805464
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0
#        StartIndex: [0, 0, 0]
#        EndIndex: [0, 0, 0]
#        StartContinuousIndex: [0, 0, 0]
#        EndContinuousIndex: [0, 0, 0]
#    DisplacementFieldSetTime: 805949
#    m_IdentityJacobian: [1, 0, 0]
# [0, 1, 0]
# [0, 0, 1]
#
#     CoordinateTolerance: 1e-06
#     DirectionTolerance: 1e-06
#    Gaussian smoothing parameters:
#    m_GaussianSmoothingVarianceForTheUpdateField: 0
#    m_GaussianSmoothingVarianceForTheTotalField: 2
#
# aligning brain DK52 to brain DK55
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 97690799.542251
# iteration: 20 94979205.707878
# iteration: 30 93090957.637114
# iteration: 40 91658404.694298
# iteration: 50 90504811.740748
# iteration: 60 89521175.303705
# iteration: 70 88653418.855682
# iteration: 80 87836078.122682
# iteration: 90 87098792.080308
# iteration: 100 86516921.526875
# itk::simple::DisplacementFieldTransform
#  GaussianSmoothingOnUpdateDisplacementFieldTransform (0x3825500)
#    RTTI typeinfo:   itk::GaussianSmoothingOnUpdateDisplacementFieldTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 1051232
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    DisplacementField:
#      Image (0x62e5fb70)
#        RTTI typeinfo:   itk::Image<itk::Vector<double, 3u>, 3u>
#        Reference Count: 3
#        Modified Time: 1025117
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        Source: (none)
#        Source output name: (none)
#        Release Data: Off
#        Data Released: False
#        Global Release Data: Off
#        PipelineMTime: 0
#        UpdateMTime: 1025110
#        RealTimeStamp: 0 seconds
#        LargestPossibleRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 265, 121]
#        BufferedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 265, 121]
#        RequestedRegion:
#          Dimension: 3
#          Index: [0, 0, 0]
#          Size: [468, 265, 121]
#        Spacing: [41.6, 41.6, 80]
#        Origin: [31.2, 26, 40]
#        Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        IndexToPointMatrix:
# 41.6 0 0
# 0 41.6 0
# 0 0 80
#
#        PointToIndexMatrix:
# 0.0240385 0 0
# 0 0.0240385 0
# 0 0 0.0125
#
#        Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#        PixelContainer:
#          ImportImageContainer (0x35c0440)
#            RTTI typeinfo:   itk::ImportImageContainer<unsigned long, itk::Vector<double, 3u> >
#            Reference Count: 1
#            Modified Time: 1025108
#            Debug: Off
#            Object Name:
#            Observers:
#              none
#            Pointer: 0x4b0ea240
#            Container manages memory: true
#            Size: 15006420
#            Capacity: 15006420
#    InverseDisplacementField: (null)
#    Interpolator:
#      VectorLinearInterpolateImageFunction (0x3855d60)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 1024632
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0x62e5fb70
#        StartIndex: [0, 0, 0]
#        EndIndex: [467, 264, 120]
#        StartContinuousIndex: [-0.5, -0.5, -0.5]
#        EndContinuousIndex: [467.5, 264.5, 120.5]
#    InverseInterpolator:
#      VectorLinearInterpolateImageFunction (0x69db9e00)
#        RTTI typeinfo:   itk::VectorLinearInterpolateImageFunction<itk::Image<itk::Vector<double, 3u>, 3u>, double>
#        Reference Count: 1
#        Modified Time: 1024633
#        Debug: Off
#        Object Name:
#        Observers:
#          none
#        InputImage: 0
#        StartIndex: [0, 0, 0]
#        EndIndex: [0, 0, 0]
#        StartContinuousIndex: [0, 0, 0]
#        EndContinuousIndex: [0, 0, 0]
#    DisplacementFieldSetTime: 1025118
#    m_IdentityJacobian: [1, 0, 0]
# [0, 1, 0]
# [0, 0, 1]
#
#     CoordinateTolerance: 1e-06
#     DirectionTolerance: 1e-06
#    Gaussian smoothing parameters:
#    m_GaussianSmoothingVarianceForTheUpdateField: 0
#    m_GaussianSmoothingVarianceForTheTotalField: 2
