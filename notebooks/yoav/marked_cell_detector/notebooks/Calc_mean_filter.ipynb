# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from os.path import expanduser
HOME = expanduser("~")
import os
import cv2

# %%
animal = 'DK55'
section = 172
INPUT = os.path.join(HOME, 'programming/brains', animal, str(section))
INPUT = '/Users/yoavfreund/projects/butons/data/%d'%section
INPUT
# Out:
# '/Users/yoavfreund/projects/butons/data/172'

# %%
width = 60000
height = 34000
tile_height = int(height / 5)
tile_width=int(width/2)
print('width=%d, tile_width=%d ,height=%d, tile_height=%d'%(width, tile_width,height,tile_height))
origins={}
for i in range(10):
    row=int(i/2)
    col=i%2
    origins[i] = (row*tile_height,col*tile_width)
print('origins=',origins)
# Out:
# width=60000, tile_width=30000 ,height=34000, tile_height=6800
# origins= {0: (0, 0), 1: (0, 30000), 2: (6800, 0), 3: (6800, 30000), 4: (13600, 0), 5: (13600, 30000), 6: (20400, 0), 7: (20400, 30000), 8: (27200, 0), 9: (27200, 30000)}

# %%
# %%time
tile=5
file = 'tile-%d.tif'%tile
radius = 400
color = (2000)
infile = os.path.join(INPUT, file)
img = cv2.imread(infile, -1)
img.shape
# Out:
# CPU times: user 463 ms, sys: 459 ms, total: 922 ms
# Wall time: 924 ms
# (6800, 30000)

# %%
# for using tile = 5, we push the origin down 2 tile_heights

dfpath = os.path.join(INPUT, '172.csv')
df = pd.read_csv(dfpath)

# %%
in_row_min=5400; in_row_max=6800; in_col_min=8000; in_col_max=13000
#in_row_min=0; in_row_max=6800; in_col_min=0; in_col_max=30000
vimg=img[in_row_min:in_row_max, in_col_min: in_col_max]

# %%
def show_image(img,_title="",fsize=[15,15]):
    plt.figure(figsize=[15,15])
    plt.imshow(img, cmap="gray")
    plt.title(_title,fontsize=20)
    plt.tick_params(axis='x', labelsize=20)
    plt.tick_params(axis='y', labelsize=20)
    plt.show()
show_image(4*vimg,_title=f'{animal} CH3, section: {section}')

# %%
def collect_and_negatives(uimg):
    img=np.copy(uimg)
    positives=[]
    radius = 80
    a=int(radius/2)
    color = (6000)
    min_row,min_col = origins[tile]
    for index,r in df.iterrows():
        col = int(round(r['x'])-min_col)
        row = int(round(r['y'])-min_row)
        if (col<0) or (col>tile_width) or (row<0) or (row>tile_height):
            continue
        img=cv2.circle(img, (int(col), int(row)), radius, color, 2)
        I=uimg[row-a:row+a,col-a:col+a]
        if I.shape==(radius,radius):
            positives.append((col,row,I))

    return img,positives

# %%
annotated_img,positives=collect_positives(img)

# %%
vimg=annotated_img[in_row_min:in_row_max, in_col_min: in_col_max]
show_image(vimg*10)

# %%
plt.figure(figsize=[15,15])
for i in range(len(positives)):
    plt.subplot(10,10,i+1)
    plt.imshow(positives[i][2], cmap="gray")
plt.show()

# %%
def plot_dist(uimg):
    H=uimg.flatten()
    H=np.sort(H)

    H=H[0:-1:1000]

    plt.plot(H,np.arange(0,1,1./H.shape[0]))
    plt.grid()
    plt.figure()
    plt.hist(H,bins=100);
plot_dist(img)

# %%
for i in [10,20,30,40]:
    plt.hist(positives[i][2].flatten(),bins=100);

# %%
positives[0]
# Out:
# (14627,
#  5771,
#  array([[ 514,  514,  514, ...,  996, 1016, 1107],
#         [ 514,  514,  514, ..., 1030, 1103, 1254],
#         [ 514,  514,  514, ..., 1003, 1227, 1282],
#         ...,
#         [ 420,  343,  521, ...,  776,  711,  660],
#         [ 516,  505,  519, ...,  771,  778,  783],
#         [ 514,  514,  514, ...,  780,  781,  782]], dtype=uint16))

# %%
for i in range(len(positives)):
    _shape=positives[i][2].shape
    if _shape !=(80,80):
        print(i,_shape)

# %%
S=np.stack([I for (x,y,I)in positives])
S.shape

Mean=np.mean(S,axis=0)
Mean.shape

plt.imshow(Mean, cmap="gray")
plt.show()

_mean=np.mean(Mean.flatten())
_std=np.std(Mean.flatten())
print('before: mean=%5.2f std=%5.2f'%(_mean,_std))

Mean = (Mean-_mean)/_std

_mean=np.mean(Mean.flatten())
_std=np.std(Mean.flatten())
print('after: mean=%5.2f std=%5.2f'%(_mean,_std))

import pickle as pk
with open('mean.pkl','wb') as pkl_file:
    pk.dump({'Mean':Mean},pkl_file)

# !ls -l *.pkl
# Out:
# before: mean=3795.25 std=2611.64
# after: mean= 0.00 std= 1.00
# -rw-r--r--  1 yoavfreund  staff    2351149 Aug 13 21:56 BoostedTrees.pkl
# -rw-r--r--  1 yoavfreund  staff  837047074 Aug 14 15:58 examples.pkl
# -rw-r--r--  1 yoavfreund  staff      51362 Aug 19 13:30 mean.pkl

# %%
# from scipy.signal import convolve2d

# %%
# O=convolve2d(uimg,Mean,mode='valid') #takes forevr, might be better with GPU

# %%
plt.figure(figsize=[15,15])
UPimg=uimg[in_row_min:in_row_max, in_col_min: in_col_max]
plt.imshow(5*UPimg,cmap='gray');

# %%
plt.figure(figsize=[15,15])
small=cv2.resize(S,(0,0),fx=0.05,fy=0.05)
show_image(small);

# %%
blur=cv2.GaussianBlur(small,ksize=(21,21),sigmaX=10)
relarge=cv2.resize(blur,(0,0),fx=20,fy=20) #,interpolation=cv2.INTER_AREA)
plt.figure(figsize=[15,15])
plt.imshow(relarge,cmap='gray');

# %%
relarge=cv2.resize(blur,(0,0),fx=20,fy=20) #,interpolation=cv2.INTER_AREA)
plt.figure(figsize=[15,15])
plt.imshow(relarge,cmap='gray');

# %%
blur.shape,uimg_8bit.shape,relarge.shape
# Out:
# ((340, 1500), (6800, 30000), (6800, 30000))

# %%
vimg=img[in_row_min:in_row_max, in_col_min: in_col_max]
show_image(5*vimg)

# %%
diff=S-relarge
plt.figure(figsize=[15,15])
show_image(diff[in_row_min:in_row_max, in_col_min: in_col_max]);

# %%
plt.figure(figsize=[15,15])
vdiff=diff[in_row_min:in_row_max, in_col_min: in_col_max]
show_image(vdiff>150);

# %%
plot_dist(diff[in_row_min:in_row_max, in_col_min: in_col_max])

# %%
Stats=cv2.connectedComponentsWithStats(np.int8(diff>130))
Stats[0]
# Out:
# 1428

# %%
show_image(Stats[1][in_row_min:in_row_max, in_col_min: in_col_max])

# %%
Stats[2].shape, Stats[3].shape
# Out:
# ((1428, 5), (1428, 2))

# %%
candid_coor=np.int32(Stats[3])
min_row,min_col = origins[tile]
candid_coor
# Out:
# array([[15004,  3397],
#        [12054,   132],
#        [ 2700,  1285],
#        ...,
#        [11306,  6788],
#        [12057,  6793],
#        [10951,  6796]], dtype=int32)

# %%
pos_coor=np.int32(df[['y','x']])
pos_coor -= np.array([min_row,min_col])
pos_coor.shape
# Out:
# (115, 2)

# %%
from numpy.linalg import norm
Dists=[]
for i in range(len(candid_coor)):
    c=norm(pos_coor-candid_coor[i],axis=1)
    Dists.append((i,np.min(c),np.argmin(c)))
Dists
# Out:
# [(0, 6883.693340060988, 2),
#  (1, 7221.1135567861, 80),
#  (2, 4803.230995902654, 83),
#  (3, 5106.931074529986, 80),
#  (4, 5095.394489144093, 80),
#  (5, 4619.7745615993, 83),
#  (6, 4787.012116132567, 80),
#  (7, 4780.604982635566, 80),
#  (8, 5207.772076425772, 80),
#  (9, 4458.685905062163, 80),
#  (10, 4678.404001366278, 80),
#  (11, 4453.217263956476, 80),
#  (12, 5222.061853329583, 80),
#  (13, 5210.4004644556835, 80),
#  (14, 5206.965527060843, 80),
#  (15, 5608.956409172743, 80),
#  (16, 5449.7732980372675, 80),
#  (17, 4988.958708989282, 80),
#  (18, 4410.929720591794, 80),
#  (19, 4649.097224193101, 80),
#  (20, 4399.112296816256, 80),
#  (21, 4423.491155185008, 80),
#  (22, 5060.805469488034, 80),
#  (23, 4411.83068578113, 80),
#  (24, 4302.665801569999, 80),
#  (25, 4296.836627101384, 80),
#  (26, 4980.424479901287, 80),
#  (27, 4998.182569694709, 80),
#  (28, 4990.70215500785, 80),
#  (29, 4419.296776637659, 80),
#  (30, 4333.031848486692, 80),
#  (31, 3954.1705830679584, 80),
#  (32, 4233.360131148778, 80),
#  (33, 4081.805972850743, 80),
#  (34, 4297.989879001578, 80),
#  (35, 4274.660805256951, 80),
#  (36, 3042.4971651589094, 80),
#  (37, 3013.4486887949492, 80),
#  (38, 2928.6846877053868, 80),
#  (39, 2855.0257441921603, 80),
#  (40, 2690.7710790775195, 80),
#  (41, 2702.348053082726, 80),
#  (42, 2714.0007369195755, 80),
#  (43, 2710.6871822473354, 80),
#  (44, 2672.31828194173, 80),
#  (45, 2647.3537731100464, 80),
#  (46, 6407.344613800635, 1),
#  (47, 2628.236100505432, 80),
#  (48, 2747.734521383025, 80),
#  (49, 2873.950069155691, 80),
#  (50, 2862.446506050375, 80),
#  (51, 2817.2202611794487, 80),
#  (52, 4487.730161228503, 1),
#  (53, 2525.8315462437317, 80),
#  (54, 2519.508880714652, 80),
#  (55, 2952.2035837658623, 80),
#  (56, 2602.3452883889177, 80),
#  (57, 2939.8221034613643, 80),
#  (58, 2633.312742535531, 80),
#  (59, 4547.304476280426, 1),
#  (60, 4535.427322755817, 1),
#  (61, 2459.444042868225, 80),
#  (541, 1838.0220346883766, 1),
#  (542, 5631.395209004603, 2),
#  (543, 1823.951753747889, 1),
#  (544, 1770.4759247162895, 80),
#  (545, 1808.1219538515647, 1),
#  (546, 1643.4235607414175, 80),
#  (547, 1468.2945889704831, 80),
#  (548, 1782.1806866869588, 1),
#  (549, 1454.960136910974, 80),
#  (550, 1708.4100795769148, 80),
#  (551, 746.1970249203624, 82),
#  (552, 1797.0901479892432, 1),
#  (553, 1797.52385241476, 1),
#  (554, 1695.5367881588415, 80),
#  (555, 1790.2513789968157, 1),
#  (556, 1793.5687887560935, 1),
#  (557, 1446.6471580865875, 80),
#  (558, 1489.4163286334683, 80),
#  (559, 1782.124855334216, 1),
#  (560, 1457.8923142674153, 80),
#  (561, 1424.1699336806687, 80),
#  (562, 1600.4155710314742, 80),
#  (563, 1772.4629756358804, 1),
#  (564, 1767.8305914312039, 1),
#  (565, 1762.77111389993, 1),
#  (566, 1760.5661021387411, 1),
#  (567, 5438.927100081412, 2),
#  (568, 1753.1106639342538, 1),
#  (569, 1758.2377541163198, 1),
#  (570, 1737.647259946621, 1),
#  (571, 1396.683213903568, 80),
#  (572, 1740.6493041391193, 1),
#  (573, 1586.8096924332167, 80),
#  (574, 1583.864261860845, 80),
#  (575, 1854.154254640104, 1),
#  (576, 1716.5663401103961, 1),
#  (577, 1720.383678136944, 1),
#  (578, 1871.5902329302746, 1),
#  (579, 1709.1342837822897, 1),
#  (580, 1863.667888868615, 1),
#  (581, 1830.4234482763818, 1),
#  (582, 1806.1165521637854, 1),
#  (583, 1814.961432097112, 1),
#  (584, 1802.3640031913642, 1),
#  (585, 1644.1611843125356, 80),
#  (586, 1645.8001093693001, 80),
#  (587, 1765.306772207029, 1),
#  (588, 488.18541559534526, 80),
#  (589, 370.11484704075303, 80),
#  (590, 1567.7898456106927, 80),
#  (591, 1769.814114532936, 1),
#  (592, 1721.9282795749652, 1),
#  (593, 1723.7871098253404, 1),
#  (594, 1739.134554886424, 1),
#  (595, 1768.7340105284345, 1),
#  (596, 1892.848118576871, 1),
#  (597, 1690.2384447171944, 1),
#  (598, 1712.201214810923, 1),
#  (599, 1678.2139315355478, 1),
#  (600, 1749.2081065442155, 1),
#  (601, 1751.470810490429, 1),
#  (602, 1562.8681966180002, 80),
#  (603, 1522.7150094485835, 80),
#  (604, 1718.728890779462, 1),
#  (605, 1722.6737938449055, 1),
#  (606, 1700.7307253060374, 1),
#  (607, 1712.1685080622176, 1),
#  (608, 1722.8099140648105, 1),
#  (609, 581.4894668005604, 82),
#  (610, 1625.0249228858, 1),
#  (611, 1677.6820318522816, 1),
#  (612, 1708.627812017585, 1),
#  (613, 1734.9066257294655, 1),
#  (614, 1879.8789854668837, 1),
#  (615, 617.1458498604685, 82),
#  (616, 1677.201538277377, 1),
#  (617, 1679.742837460544, 1),
#  (618, 1614.0012391568973, 1),
#  (619, 1615.0374608658462, 1),
#  (620, 1616.1237576373908, 1),
#  (621, 1613.1366960056423, 1),
#  (622, 1735.8908375816723, 1),
#  (623, 1877.761699470942, 1),
#  (624, 1628.6239590525495, 1),
#  (625, 1609.1643794218166, 1),
#  (626, 1538.407618285869, 80),
#  (627, 1684.2523563884363, 1),
#  (628, 1873.107578330727, 1),
#  (629, 1719.655779509376, 1),
#  (630, 1705.2184610776415, 1),
#  (631, 1869.695697165718, 1),
#  (632, 1688.730292261023, 1),
#  (633, 1698.0394577276465, 1),
#  (634, 1869.0238093721546, 1),
#  (635, 1622.6755683130255, 1),
#  (636, 1671.4320207534615, 1),
#  (637, 1696.5264513116203, 1),
#  (638, 1867.1703189586108, 1),
#  (639, 1863.498054734697, 1),
#  (640, 453.10043036836765, 80),
#  (641, 445.31449560956355, 80),
#  (642, 447.7153113307607, 80),
#  (643, 1942.6541122907083, 1),
#  (644, 1558.4428125536078, 80),
#  (645, 1621.7709456023683, 1),
#  (646, 1240.4922410075767, 80),
#  (647, 1246.4417355015034, 80),
#  (648, 1972.4025958206403, 1),
#  (649, 411.17514516322603, 80),
#  (650, 1552.6561113137707, 80),
#  (651, 1849.1892818205497, 1),
#  (652, 5176.083847852544, 2),
#  (653, 499.7299270606074, 80),
#  (654, 1624.241669210589, 1),
#  (655, 1647.6559106803822, 1),
#  (656, 1648.2675753651165, 1),
#  (657, 1645.4461401091194, 1),
#  (658, 1632.7354347842152, 1),
#  (659, 1357.7647071565825, 80),
#  (660, 396.5362530715193, 80),
#  (661, 1629.091771509512, 1),
#  (662, 1595.3798920633292, 1),
#  (663, 389.59722791621607, 80),
#  (664, 2500.6049268127103, 1),
#  (665, 1577.3357283723715, 1),
#  (666, 1578.3957045050522, 1),
#  (667, 1880.0558502342424, 1),
#  (668, 2473.3252919905217, 1),
#  (669, 2479.743535126163, 1),
#  (670, 2482.9699957913303, 1),
#  (671, 1575.2206194689047, 1),
#  (672, 2465.0517235952675, 1),
#  (673, 1538.9821311503263, 1),
#  (674, 1883.3441002642082, 1),
#  (675, 1844.1784078553787, 1),
#  (676, 1386.2135477623929, 80),
#  (677, 1583.7730266676472, 1),
#  (678, 2137.682155981099, 1),
#  (679, 1427.720210685553, 80),
#  (680, 1551.0825252061863, 1),
#  (681, 1549.9177397526619, 1),
#  (682, 1552.9082394011566, 1),
#  (683, 1578.837863746623, 1),
#  (684, 3791.191105708073, 2),
#  (685, 1842.2152425816046, 1),
#  (686, 1530.655088516025, 1),
#  (687, 1546.3767328823853, 1),
#  (688, 1553.574266007261, 1),
#  (689, 1964.4790658085415, 1),
#  (690, 1968.0553853995066, 1),
#  (691, 1838.8651391551257, 1),
#  (692, 1443.6845223247356, 80),
#  (693, 2034.3672234874412, 1),
#  (694, 2050.836414734242, 1),
#  (695, 1871.2479792908262, 1),
#  (696, 2289.80894399511, 1),
#  (697, 3788.9887833035345, 2),
#  (698, 1435.3442095887663, 80),
#  (699, 2612.531530910201, 1),
#  (700, 514.2188250151875, 81),
#  (941, 1094.9853880303608, 1),
#  (942, 1268.6283931869095, 1),
#  (943, 2309.5768010611814, 2),
#  (944, 3279.08783047969, 2),
#  (945, 2316.4664901526203, 2),
#  (946, 2493.9819566308015, 2),
#  (947, 391.26589424584404, 81),
#  (948, 3289.426089760948, 2),
#  (949, 1753.624817342638, 2),
#  (950, 4748.492076438582, 2),
#  (951, 5083.790908367495, 2),
#  (952, 2503.896563358798, 2),
#  (953, 2509.0, 2),
#  (954, 2834.2535172422386, 2),
#  (955, 3494.280040294424, 2),
#  (956, 3263.0740108063746, 2),
#  (957, 889.2429364352578, 1),
#  (958, 2031.6190587804595, 2),
#  (959, 2195.8073686004427, 2),
#  (960, 1489.6499588829586, 1),
#  (961, 2193.589979918763, 2),
#  (962, 901.9201738513226, 1),
#  (963, 3221.3664802378507, 2),
#  (964, 3274.184631324263, 2),
#  (965, 902.2372193608508, 1),
#  (966, 920.271699010678, 1),
#  (967, 3223.0079118736276, 2),
#  (968, 3449.558812370069, 2),
#  (969, 1351.0766077465778, 1),
#  (970, 1535.410368598571, 1),
#  (971, 1355.1461175828974, 1),
#  (972, 3217.0130556154104, 2),
#  (973, 1339.224402406109, 1),
#  (974, 1744.8349492143948, 2),
#  (975, 1166.8247511944542, 1),
#  (976, 1351.6870939681269, 1),
#  (977, 1483.5538412878718, 1),
#  (978, 1597.45860666247, 1),
#  (979, 1595.2962107395604, 1),
#  (980, 2769.8485518165066, 2),
#  (981, 2769.8797807847186, 2),
#  (982, 908.5268295432998, 1),
#  (983, 2914.9162938238896, 2),
#  (984, 1157.8851411085643, 1),
#  (985, 1477.7523473166943, 1),
#  (986, 3208.0804229320684, 2),
#  (987, 1136.458094256009, 1),
#  (988, 948.6226857924071, 1),
#  (989, 1304.2948286334652, 1),
#  (990, 1473.1306798787405, 1),
#  (991, 2952.736019355608, 2),
#  (992, 984.6486683076355, 1),
#  (993, 866.0577347960124, 1),
#  (994, 1744.2055498134387, 2),
#  (995, 965.0699456516093, 1),
#  (996, 2084.261260015164, 2),
#  (997, 3278.7011147709086, 2),
#  (998, 2809.854978464191, 2),
#  (999, 3285.5923362462363, 2),
#  ...]

# %%
SD=np.sort([d[1] for d in Dists])
plt.plot(SD[:200])
plt.grid()

# %%
candid_coor.shape,pos_coor.shape
# Out:
# ((1428, 2), (115, 2))

# %%
seg=Stats[1]
seg.shape
# Out:
# (6800, 30000)

# %%
for i in range(len(pos_coor)):
    c=pos_coor[i]-np.array([min_col,min_row])
    if c[0]<0 or c[0]>=tile_height or c[1]<0 or c[1] >=tile_width:
        continue
    print(np.array([min_col,min_row]),c)
    print(i,seg[c[0],c[1]])
# Out:
# [30000 13600] [5491 7214]
# 80 0
# [30000 13600] [5928 6556]
# 81 0
# [30000 13600] [5852 6214]
# 82 0
# [30000 13600] [5793 4358]
# 83 0
# [30000 13600] [6061 5566]
# 84 0

# %%
tile_width,tile_height
# Out:
# (30000, 6800)
