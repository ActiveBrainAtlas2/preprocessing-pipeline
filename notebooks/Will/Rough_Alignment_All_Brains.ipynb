# %%
from rough_alignment_affine import get_rough_alignment_affine_transform
from toolbox.brain_lists import get_list_of_brains_to_align
from toolbox.save_transform import save_affine_transform
list_of_brains = get_list_of_brains_to_align()
print(list_of_brains)
# Out:
# ['DK39', 'DK41', 'DK43', 'DK54', 'DK55']

# %%
braini
# Out:
# 'DK39'

# %%
for braini in list_of_brains:
    affine_transform = get_rough_alignment_affine_transform(fixed_brain = braini)
    print('saving results')
    save_affine_transform(affine_transform,braini)
# Out:
# aligning brain DK52 to brain DK39
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.274644
# iteration: 20 -0.291827
# iteration: 30 -0.308896
# iteration: 40 -0.323968
# iteration: 50 -0.340122
# iteration: 60 -0.356133
# iteration: 70 -0.365911
# iteration: 80 -0.373418
# iteration: 90 -0.381937
# iteration: 100 -0.388885
# switching to higher resolution
# iteration: 10 -0.392214
# iteration: 20 -0.396734
# iteration: 30 -0.401206
# iteration: 40 -0.404351
# iteration: 50 -0.407629
# iteration: 60 -0.411466
# iteration: 70 -0.416159
# iteration: 80 -0.419560
# iteration: 90 -0.422263
# iteration: 100 -0.423736
# switching to higher resolution
# iteration: 10 -0.423372
# itk::simple::AffineTransform
#  AffineTransform (0x5620ff03a220)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 39595296
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
# ...
