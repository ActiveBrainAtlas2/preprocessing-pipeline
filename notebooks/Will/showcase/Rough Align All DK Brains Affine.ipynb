# %%
import sys
sys.path.append('/home/zhw272/programming/pipeline_utility')
from notebooks.Will.toolbox.rough_alignment.rough_alignment_affine import get_rough_alignment_affine_transform
import SimpleITK as sitk

# %%
list_of_brains_to_align = ['DK39', 'DK41', 'DK43', 'DK54', 'DK55']
save_path = '/net/birdstore/Active_Atlas_Data/data_root/tfm'
for braini in list_of_brains_to_align:
    transformi = get_rough_alignment_affine_transform(fixed_brain = braini)
    sitk.WriteTransform(transformi, save_path+'/affine/'+braini+'_affine.tfm')
# Out:
# aligning brain DK52 to brain DK39
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.279569
# iteration: 20 -0.301494
# iteration: 30 -0.317448
# iteration: 40 -0.333938
# iteration: 50 -0.346920
# iteration: 60 -0.362512
# iteration: 70 -0.373968
# iteration: 80 -0.385338
# iteration: 90 -0.391480
# iteration: 100 -0.399016
# switching to higher resolution
# iteration: 10 -0.394337
# iteration: 20 -0.399093
# iteration: 30 -0.401802
# iteration: 40 -0.405217
# iteration: 50 -0.408662
# iteration: 60 -0.411613
# iteration: 70 -0.414231
# iteration: 80 -0.418767
# iteration: 90 -0.420112
# iteration: 100 -0.421542
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x2a83a40)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 19794470
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.935282 0.165605 0.101765
#      -0.193829 1.01103 0.0493076
#      -0.115888 -0.0612461 0.966368
#    Offset: [-112.227, 1953.72, 1566.25]
#    Center: [9058.4, 5454.8, 4680]
#    Translation: [681.133, 488.874, 25.0035]
#    Inverse:
#      1.02107 -0.173227 -0.0986862
#      0.189197 0.953943 -0.0685972
#      0.134439 0.0396849 1.01862
#    Singular: 0
#
# aligning brain DK52 to brain DK41
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.357032
# iteration: 20 -0.382498
# iteration: 30 -0.390412
# iteration: 40 -0.395557
# iteration: 50 -0.400244
# iteration: 60 -0.405341
# iteration: 70 -0.407382
# iteration: 80 -0.413667
# iteration: 90 -0.417717
# iteration: 100 -0.423142
# switching to higher resolution
# iteration: 10 -0.421167
# iteration: 20 -0.425169
# iteration: 30 -0.429042
# iteration: 40 -0.433882
# iteration: 50 -0.436269
# iteration: 60 -0.440135
# iteration: 70 -0.442734
# iteration: 80 -0.445623
# iteration: 90 -0.446747
# iteration: 100 -0.448506
# switching to higher resolution
# iteration: 10 -0.452044
# itk::simple::AffineTransform
#  AffineTransform (0x2af2310)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 39185590
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.973945 0.139551 -0.0893363
#      -0.13583 0.943396 0.0120535
#      0.0542486 0.00828462 1.00026
#    Offset: [593.013, 1752.86, -445.878]
#    Center: [9354.8, 5194.8, 4660]
#    Translation: [657.908, 244.318, 105.849]
#    Inverse:
#      1.00091 -0.14886 0.0911885
#      0.14482 1.03857 0.000419102
#      -0.0554835 -0.000528623 0.994792
#    Singular: 0
#
# aligning brain DK52 to brain DK43
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.272812
# iteration: 20 -0.302507
# iteration: 30 -0.324250
# iteration: 40 -0.349180
# iteration: 50 -0.367697
# iteration: 60 -0.390022
# iteration: 70 -0.399421
# iteration: 80 -0.404883
# iteration: 90 -0.409293
# switching to higher resolution
# iteration: 10 -0.409270
# iteration: 20 -0.414114
# iteration: 30 -0.417656
# iteration: 40 -0.422855
# iteration: 50 -0.426177
# iteration: 60 -0.429379
# iteration: 70 -0.429351
# iteration: 80 -0.432943
# iteration: 90 -0.436128
# switching to higher resolution
# iteration: 10 -0.436311
# iteration: 20 -0.437552
# iteration: 30 -0.438599
# iteration: 40 -0.439162
# itk::simple::AffineTransform
#  AffineTransform (0x2b103f0)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 54480352
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.972859 0.209178 -0.0326144
#      -0.247538 1.01281 -0.10621
#      -0.0155836 0.117714 1.02
#    Offset: [433.634, 3232.8, -301.714]
#    Center: [8767.2, 5194.8, 3910]
#    Translation: [1154.8, 713.862, 251.38]
#    Inverse:
#      0.976448 -0.202842 0.0101004
#      0.237342 0.926238 0.104036
#      -0.0124726 -0.109992 0.968537
#    Singular: 0
#
# aligning brain DK52 to brain DK54
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.282391
# iteration: 20 -0.321369
# iteration: 30 -0.337753
# iteration: 40 -0.351785
# iteration: 50 -0.358415
# iteration: 60 -0.366729
# iteration: 70 -0.368486
# iteration: 80 -0.371720
# iteration: 90 -0.377185
# iteration: 100 -0.378148
# switching to higher resolution
# iteration: 10 -0.382652
# iteration: 20 -0.388298
# iteration: 30 -0.393763
# iteration: 40 -0.399082
# iteration: 50 -0.403466
# iteration: 60 -0.408239
# iteration: 70 -0.411554
# iteration: 80 -0.415245
# iteration: 90 -0.416713
# iteration: 100 -0.418430
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x1dd3a00)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 74176392
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.998893 0.132232 -0.0916518
#      -0.103733 0.907968 -0.122713
#      0.0643827 0.138528 0.955204
#    Offset: [744.668, 2586.83, -1102.22]
#    Center: [9744.8, 6167.2, 3830]
#    Translation: [1198.36, 538.406, 207.935]
#    Inverse:
#      0.980318 -0.1541 0.0742647
#      0.101087 1.0643 0.146427
#      -0.0807355 -0.143962 1.02066
#    Singular: 0
#
# aligning brain DK52 to brain DK55
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.365521
# iteration: 20 -0.375705
# iteration: 30 -0.383130
# iteration: 40 -0.388142
# iteration: 50 -0.390713
# iteration: 60 -0.392513
# iteration: 70 -0.394587
# iteration: 80 -0.398814
# iteration: 90 -0.402619
# iteration: 100 -0.406754
# switching to higher resolution
# iteration: 10 -0.411965
# iteration: 20 -0.417024
# iteration: 30 -0.420872
# iteration: 40 -0.424109
# iteration: 50 -0.426923
# iteration: 60 -0.427747
# iteration: 70 -0.428113
# iteration: 80 -0.428814
# iteration: 90 -0.429975
# iteration: 100 -0.431359
# switching to higher resolution
# iteration: 10 -0.430489
# iteration: 20 -0.430823
# iteration: 30 -0.431985
# iteration: 40 -0.431955
# iteration: 50 -0.432680
# iteration: 60 -0.432688
# iteration: 70 -0.432884
# iteration: 80 -0.432956
# itk::simple::AffineTransform
#  AffineTransform (0x2ac9210)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 96435542
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.919324 0.131311 -0.0181173
#      -0.140288 0.889142 -0.0141436
#      -0.0373505 0.000256352 0.954207
#    Offset: [632.355, 2463.34, 625.33]
#    Center: [9744.8, 5517.2, 4840]
#    Translation: [482.962, 416.182, 41.1321]
#    Inverse:
#      1.06449 -0.157212 0.017881
#      0.168616 1.09977 0.0195028
#      0.0416221 -0.00644921 1.04869
#    Singular: 0
