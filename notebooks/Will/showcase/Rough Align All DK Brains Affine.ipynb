# %%
import sys
sys.path.append('/home/zhw272/programming/pipeline_utility')
from notebooks.Will.toolbox.rough_alignment.rough_alignment_affine import get_rough_alignment_affine_transform
import SimpleITK as sitk

# %%
list_of_brains_to_align = ['DK39', 'DK41', 'DK43', 'DK54', 'DK55']
save_path = '/net/birdstore/Active_Atlas_Data/data_root/tfm'
for braini in list_of_brains_to_align:
    transformi = get_rough_alignment_affine_transform(fixed_brain = braini)
    sitk.WriteTransform(transformi, save_path+'/affine/'+braini+'_affine.tfm')
# Out:
# aligning brain DK52 to brain DK39
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.277946
# iteration: 20 -0.298479
# iteration: 30 -0.314351
# iteration: 40 -0.332791
# iteration: 50 -0.347234
# iteration: 60 -0.361429
# iteration: 70 -0.369165
# iteration: 80 -0.377474
# iteration: 90 -0.389403
# iteration: 100 -0.393646
# switching to higher resolution
# iteration: 10 -0.396424
# iteration: 20 -0.400183
# iteration: 30 -0.406300
# iteration: 40 -0.410212
# iteration: 50 -0.414020
# iteration: 60 -0.416319
# iteration: 70 -0.419536
# iteration: 80 -0.422448
# iteration: 90 -0.424024
# iteration: 100 -0.425193
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x1749400)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 19794470
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.935236 0.174201 0.10542
#      -0.193946 1.011 0.0567235
#      -0.117402 -0.0560011 0.9828
#    Offset: [-186.24, 2029.41, 1533.32]
#    Center: [9058.4, 5454.8, 4680]
#    Translation: [670.705, 598.029, 83.8814]
#    Inverse:
#      1.01928 -0.181105 -0.0988803
#      0.188102 0.952547 -0.0751542
#      0.132477 0.0326431 1.00141
#    Singular: 0
#
# aligning brain DK52 to brain DK41
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.361101
# iteration: 20 -0.382999
# iteration: 30 -0.389804
# iteration: 40 -0.396147
# iteration: 50 -0.403168
# iteration: 60 -0.409112
# iteration: 70 -0.413851
# iteration: 80 -0.418119
# iteration: 90 -0.421654
# iteration: 100 -0.425362
# switching to higher resolution
# iteration: 10 -0.422138
# iteration: 20 -0.426639
# iteration: 30 -0.431575
# iteration: 40 -0.434719
# iteration: 50 -0.436907
# iteration: 60 -0.438518
# iteration: 70 -0.441578
# iteration: 80 -0.444930
# iteration: 90 -0.448599
# iteration: 100 -0.451367
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x2826090)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 39184512
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.972829 0.14068 -0.0916034
#      -0.133566 0.938763 0.0175925
#      0.0522966 0.00530118 0.992832
#    Offset: [615.584, 1762.52, -376.557]
#    Center: [9354.8, 5194.8, 4660]
#    Translation: [665.338, 276.893, 106.805]
#    Inverse:
#      1.00212 -0.150712 0.0951311
#      0.143585 1.04374 -0.00524681
#      -0.0535527 0.00236559 1.00224
#    Singular: 0
#
# aligning brain DK52 to brain DK43
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.266840
# iteration: 20 -0.288450
# iteration: 30 -0.311633
# iteration: 40 -0.327093
# iteration: 50 -0.342009
# iteration: 60 -0.357247
# iteration: 70 -0.372015
# iteration: 80 -0.384826
# iteration: 90 -0.393073
# iteration: 100 -0.399786
# switching to higher resolution
# iteration: 10 -0.403512
# iteration: 20 -0.407762
# iteration: 30 -0.412084
# iteration: 40 -0.417428
# iteration: 50 -0.420826
# iteration: 60 -0.424579
# iteration: 70 -0.427118
# iteration: 80 -0.429635
# iteration: 90 -0.430243
# iteration: 100 -0.431361
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x28129c0)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 54474354
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.97102 0.173059 -0.0269987
#      -0.243265 1.00806 -0.0799155
#      -0.00528911 0.0608896 1.03601
#    Offset: [610.293, 2964.79, -118.963]
#    Center: [8767.2, 5194.8, 3910]
#    Translation: [1149.66, 561.407, 291.771]
#    Inverse:
#      0.987262 -0.17025 0.0125957
#      0.23754 0.946445 0.0791971
#      -0.00892076 -0.0564948 0.960652
#    Singular: 0
#
# aligning brain DK52 to brain DK54
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.292377
# iteration: 20 -0.335006
# iteration: 30 -0.353430
# iteration: 40 -0.362505
# iteration: 50 -0.369991
# iteration: 60 -0.374288
# iteration: 70 -0.378232
# iteration: 80 -0.380649
# iteration: 90 -0.383838
# iteration: 100 -0.387375
# switching to higher resolution
# iteration: 10 -0.387168
# iteration: 20 -0.393277
# iteration: 30 -0.399027
# iteration: 40 -0.403172
# iteration: 50 -0.407177
# iteration: 60 -0.411163
# iteration: 70 -0.414643
# iteration: 80 -0.418248
# iteration: 90 -0.419202
# iteration: 100 -0.420628
# switching to higher resolution
# iteration: 10 -0.421115
# iteration: 20 -0.421721
# iteration: 30 -0.422302
# iteration: 40 -0.422844
# iteration: 50 -0.423013
# iteration: 60 -0.423245
# iteration: 70 -0.423431
# itk::simple::AffineTransform
#  AffineTransform (0x281e350)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 74180250
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      1.00468 0.148573 -0.0944646
#      -0.10577 0.936341 -0.152131
#      0.0598267 0.165158 0.967047
#    Offset: [613.192, 2359.05, -1178.63]
#    Center: [9744.8, 6167.2, 3830]
#    Translation: [1213.26, 353.077, 296.728]
#    Inverse:
#      0.973696 -0.166653 0.068897
#      0.0974972 1.02247 0.170373
#      -0.0768892 -0.164313 1.00072
#    Singular: 0
#
# aligning brain DK52 to brain DK55
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.369657
# iteration: 20 -0.380264
# iteration: 30 -0.388778
# iteration: 40 -0.394898
# iteration: 50 -0.401476
# iteration: 60 -0.404739
# iteration: 70 -0.407838
# iteration: 80 -0.409663
# iteration: 90 -0.413805
# iteration: 100 -0.416156
# switching to higher resolution
# iteration: 10 -0.417270
# iteration: 20 -0.422816
# iteration: 30 -0.425633
# iteration: 40 -0.428325
# switching to higher resolution
# iteration: 10 -0.429732
# iteration: 20 -0.430795
# iteration: 30 -0.431145
# iteration: 40 -0.431698
# itk::simple::AffineTransform
#  AffineTransform (0x3193780)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 96424458
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.920883 0.124682 -0.0156608
#      -0.139594 0.887807 -0.0109298
#      -0.0381484 -0.00311649 0.952225
#    Offset: [643.864, 2462.63, 651.668]
#    Center: [9744.8, 5517.2, 4840]
#    Translation: [484.98, 430.424, 31.4925]
#    Inverse:
#      1.06393 -0.14936 0.0157835
#      0.167817 1.10286 0.0154188
#      0.0431727 -0.00237424 1.05086
#    Singular: 0
