# %%
import sys
sys.path.append('/home/zhw272/programming/pipeline_utility')
from notebooks.Will.rough_alignment_affine import get_rough_alignment_affine_transform
import SimpleITK as sitk

# %%
list_of_brains_to_align = ['DK39', 'DK41', 'DK43', 'DK54', 'DK55']
save_path = '/net/birdstore/Active_Atlas_Data/data_root/tfm'
for braini in list_of_brains_to_align:
    transformi = get_rough_alignment_affine_transform(fixed_brain = braini)
    sitk.WriteTransform(transformi, save_path+'/affine/'+braini+'_demons.tfm')
# Out:
# aligning brain DK52 to brain DK39
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.283374
# iteration: 20 -0.301240
# iteration: 30 -0.321906
# iteration: 40 -0.338762
# iteration: 50 -0.354740
# iteration: 60 -0.371141
# iteration: 70 -0.380861
# iteration: 80 -0.390762
# iteration: 90 -0.396397
# iteration: 100 -0.401255
# switching to higher resolution
# iteration: 10 -0.402916
# iteration: 20 -0.408935
# iteration: 30 -0.413637
# iteration: 40 -0.420149
# iteration: 50 -0.422730
# iteration: 60 -0.424683
# iteration: 70 -0.425958
# iteration: 80 -0.426768
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x27da410)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 79183928
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.934573 0.181778 0.105903
#      -0.196644 1.0087 0.0660883
#      -0.113087 -0.0575936 0.97344
#    Offset: [-185.365, 1865.12, 1687.65]
#    Center: [9058.4, 5454.8, 4680]
#    Translation: [709.156, 440.604, 224.801]
#    Inverse:
#      1.01836 -0.189112 -0.0979509
#      0.190039 0.952253 -0.0853248
#      0.129549 0.0343705 1.01086
#    Singular: 0
#
# aligning brain DK52 to brain DK41
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.355846
# iteration: 20 -0.382573
# iteration: 30 -0.392825
# iteration: 40 -0.402709
# iteration: 50 -0.409412
# iteration: 60 -0.414170
# iteration: 70 -0.416666
# iteration: 80 -0.418966
# iteration: 90 -0.421936
# iteration: 100 -0.425360
# switching to higher resolution
# iteration: 10 -0.422602
# iteration: 20 -0.428092
# iteration: 30 -0.432674
# iteration: 40 -0.436862
# iteration: 50 -0.443046
# iteration: 60 -0.451545
# iteration: 70 -0.452735
# iteration: 80 -0.452688
# switching to higher resolution
# iteration: 10 -0.453787
# iteration: 20 -0.454258
# iteration: 30 -0.454361
# itk::simple::AffineTransform
#  AffineTransform (0x4565b90)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 98574736
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.976038 0.143369 -0.0870644
#      -0.135142 0.942786 0.0156637
#      0.0530146 0.00859605 1.00243
#    Offset: [556.151, 1729.79, -370.49]
#    Center: [9354.8, 5194.8, 4660]
#    Translation: [671.039, 241.343, 181.444]
#    Inverse:
#      0.998572 -0.152664 0.0891146
#      0.144036 1.03882 -0.00372222
#      -0.0540456 -0.000834241 0.992892
#    Singular: 0
#
# aligning brain DK52 to brain DK43
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.267761
# iteration: 20 -0.279947
# iteration: 30 -0.296589
# iteration: 40 -0.306054
# iteration: 50 -0.315119
# iteration: 60 -0.329083
# iteration: 70 -0.337651
# iteration: 80 -0.350199
# iteration: 90 -0.365798
# iteration: 100 -0.377030
# switching to higher resolution
# iteration: 10 -0.392012
# iteration: 20 -0.398071
# iteration: 30 -0.402579
# iteration: 40 -0.406460
# iteration: 50 -0.410030
# iteration: 60 -0.413391
# iteration: 70 -0.415809
# iteration: 80 -0.419803
# iteration: 90 -0.423966
# iteration: 100 -0.426000
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x4561ef0)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 113864578
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.969453 0.14893 -0.0251331
#      -0.237457 1.0116 -0.0651767
#      3.74583e-05 0.0449764 1.04138
#    Offset: [731.625, 3008.28, -105.832]
#    Center: [8767.2, 5194.8, 3910]
#    Translation: [1139.21, 731.854, 289.947]
#    Inverse:
#      0.995451 -0.147212 0.0148111
#      0.233016 0.951332 0.0651644
#      -0.0100996 -0.0410819 0.957447
#    Singular: 0
#
# aligning brain DK52 to brain DK54
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.277226
# iteration: 20 -0.315635
# iteration: 30 -0.338565
# iteration: 40 -0.349671
# iteration: 50 -0.355058
# iteration: 60 -0.357175
# iteration: 70 -0.362624
# iteration: 80 -0.366542
# iteration: 90 -0.373802
# iteration: 100 -0.375619
# switching to higher resolution
# iteration: 10 -0.380206
# iteration: 20 -0.387152
# iteration: 30 -0.392332
# iteration: 40 -0.399614
# iteration: 50 -0.404499
# iteration: 60 -0.409305
# iteration: 70 -0.412120
# iteration: 80 -0.414428
# iteration: 90 -0.417134
# iteration: 100 -0.419827
# switching to higher resolution
# itk::simple::AffineTransform
#  AffineTransform (0x45ab000)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 133560618
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      1.00148 0.134984 -0.0991954
#      -0.104784 0.927981 -0.132529
#      0.0660654 0.134036 0.963922
#    Offset: [711.266, 2167.45, -1058.86]
#    Center: [9744.8, 6167.2, 3830]
#    Translation: [1178.26, 194.614, 273.38]
#    Inverse:
#      0.977207 -0.153618 0.0794417
#      0.0988151 1.04109 0.153307
#      -0.0807164 -0.134237 1.01067
#    Singular: 0
#
# aligning brain DK52 to brain DK55
# loading image
# aligning image center
# finding affine tranformation
# starting optimization
# iteration: 10 -0.371242
# iteration: 20 -0.383254
# iteration: 30 -0.388383
# iteration: 40 -0.393137
# iteration: 50 -0.399994
# iteration: 60 -0.402858
# iteration: 70 -0.406756
# iteration: 80 -0.410846
# iteration: 90 -0.415914
# iteration: 100 -0.417555
# switching to higher resolution
# iteration: 10 -0.416524
# iteration: 20 -0.420587
# iteration: 30 -0.425003
# iteration: 40 -0.427511
# iteration: 50 -0.430201
# iteration: 60 -0.431418
# switching to higher resolution
# iteration: 10 -0.431529
# iteration: 20 -0.431561
# itk::simple::AffineTransform
#  AffineTransform (0x2742730)
#    RTTI typeinfo:   itk::AffineTransform<double, 3u>
#    Reference Count: 2
#    Modified Time: 155806058
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    Matrix:
#      0.918084 0.123511 -0.0130869
#      -0.139935 0.88836 -0.0151288
#      -0.0406547 0.00173099 0.952412
#    Offset: [668.35, 2482.9, 653.019]
#    Center: [9744.8, 5517.2, 4840]
#    Translation: [488.186, 430.095, 36.0736]
#    Inverse:
#      1.06715 -0.148393 0.0123063
#      0.168869 1.10215 0.0198278
#      0.0452455 -0.00833745 1.05045
#    Singular: 0
