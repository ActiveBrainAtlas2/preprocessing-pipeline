# %%
import os, sys
import pandas as pd
import numpy as np

# %%
HOME = os.path.expanduser("~")
DIR = os.path.join(HOME, 'programming/pipeline_utility')
sys.path.append(DIR)
from utilities.contour_utilities import get_structure_colors
VOL_DIR = '/net/birdstore/Active_Atlas_Data/data_root/CSHL_volumes/atlasV7/10.0um_annotationAsScoreVolume'
colors = get_structure_colors()

# %%
files = os.listdir(VOL_DIR)
numpy_files = [f for f in files if f.endswith('.npy') and 'surround' not in f]

# %%
data = []
for n in numpy_files:
    structure = os.path.splitext(n)[0]
    try:
        color = colors[structure.upper()]
    except:
        sided = '{}_R'.format(structure.upper())
        color = colors[sided]

    origin_filename = os.path.join(VOL_DIR, f'{structure}_origin_wrt_canonicalAtlasSpace.txt')
    origin_wrt = np.loadtxt(origin_filename)
    x, y, z = origin_wrt

    
    data.append(
        {
            'structure': structure,
            'color': color,
            'x': origin_wrt[0],
            'y': origin_wrt[1],
            'z': origin_wrt[2]
        }
    )

df = pd.DataFrame(data)
left_sagittal = df['x'] < 0
upper_sagittal = df['y'] < 0
upper_left_sagittal = df[left_brain & upper_sagittal]
right_sagittal = df['x'] > 0
lower_sagittal = df['y'] > 0
lower_right_sagittal = df[right_sagittal & lower_sagittal]
left_structures = df[df.structure.str.contains('_L',case=True)]
right_structures = df[df.structure.str.contains('_R',case=True)]
df.set_index('structure', inplace=True)
upper_left_sagittal.set_index('structure', inplace=True)
lower_right_sagittal.set_index('structure', inplace=True)
left_structures.set_index('structure', inplace=True)
right_structures.set_index('structure', inplace=True)

# %%
df.sort_values(by=['z'], ascending=[True])
# Out:
#            color           x           y           z
# structure
# VCA_L         25  -62.893213  -50.617435 -274.883989
# VCP_L         26   15.262947  -45.451585 -261.707769
# DC_L          10    2.790296  -76.344768 -260.306855
# Sp5I_L        22  125.369255   -8.783106 -238.825551
# Sp5O_L        23   -1.700725  -12.329991 -236.866988
# Sp5C_L        21  191.735907    6.817018 -212.403919
# SNR_L         20 -271.615066 -104.468783 -208.012454
# PBG_L         14 -132.139469 -173.161062 -202.044402
# IC            11 -153.174181 -338.455615 -194.000000
# VLL_L         27 -161.679361 -108.669003 -192.318430
# SC            18 -248.125053 -317.797816 -185.000000
# 7n_L           7  -60.459405   -7.061595 -178.073663
# SNC_L         19 -264.821464  -78.641004 -170.410830
# 5N_L           5  -81.968586  -40.419902 -166.244802
# 7N_L           7  -18.479720   82.015345 -162.645484
# LRt_L         13  120.787370   92.532443 -155.926632
# Amb_L          8   83.154757   91.682636 -130.762439
# Pn_L          15 -212.831199   34.544723 -120.526282
# RMC_L         16 -218.669899  -87.339631  -98.438894
# LC_L          12  -46.951796  -88.510782  -98.338842
# RtTg          17 -175.912023   16.623092  -96.000000
# Tz_L          24 -122.406934   96.664851  -79.437832
# 10N_L          1  147.810741   19.231470  -55.142288
# 6N_L           6    2.926046   -0.468585  -49.036632
# 12N            2  141.800269   31.125366  -44.000000
# 3N_L           3 -165.582931 -127.185185  -38.941940
# 4N_L           4 -109.635453 -113.564845  -34.586841
# AP             9  169.408890    7.033750  -19.000000
# 3N_R           3 -165.582931 -127.185185  -12.058060
# 10N_R          1  147.810741   19.231470    3.142288
# Pn_R          15 -212.831199   34.544723    5.526282
# RMC_R         16 -218.669899  -87.339631   12.438894
# 4N_R           4 -109.635453 -113.564845   14.586841
# Tz_R          24 -122.406934   96.664851   19.437832
# 6N_R           6    2.926046   -0.468585   24.036632
# 7n_R           7  -60.459405   -7.061595   29.073663
# Sp5C_R        21  191.735907    6.817018   31.403919
# SNC_R         19 -264.821464  -78.641004   67.410830
# LC_R          12  -46.951796  -88.510782   68.338842
# SNR_R         20 -271.615066 -104.468783   69.012454
# 7N_R           7  -18.479720   82.015345   69.645484
# LRt_R         13  120.787370   92.532443   72.926632
# VLL_R         27 -161.679361 -108.669003   98.318430
# 5N_R           5  -81.968586  -40.419902  108.244802
# DC_R          10    2.790296  -76.344768  114.306855
# Amb_R          8   83.154757   91.682636  117.762439
# Sp5O_R        23   -1.700725  -12.329991  138.866988
# Sp5I_R        22  125.369255   -8.783106  147.825551
# PBG_R         14 -132.139469 -173.161062  169.044402
# VCP_R         26   15.262947  -45.451585  187.707769
# VCA_R         25  -62.893213  -50.617435  199.883989
